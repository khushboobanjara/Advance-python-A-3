# %%
# 1. Load the Titanic dataset into a DataFrame named df .
import pandas as pd
df = pd.read_csv('/train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 2. Display the first 10 rows of the dataset.
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# 3. Display the last 7 rows of the dataset.
df.tail(7)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch           Ticket    Fare Cabin Embarked
# 884    male  25.0      0      0  SOTON/OQ 392076   7.050   NaN        S
# 885  female  39.0      0      5           382652  29.125   NaN        Q
# 886    male  27.0      0      0           211536  13.000   NaN        S
# ...

# %%
# 4. Show 5 random rows from the dataset.
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 380          381         1       1
# 310          311         1       1
# 272          273         1       2
# 411          412         0       3
# 432          433         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 380                              Bidois, Miss. Rosalie  female  42.0      0
# 310                     Hays, Miss. Margaret Bechstein  female  24.0      0
# 272          Mellinger, Mrs. (Elizabeth Anne Maidment)  female  41.0      0
# 411                                    Hart, Mr. Henry    male   NaN      0
# 432  Louch, Mrs. Charles Alexander (Alice Adelaide ...  female  42.0      1
#
#      Parch      Ticket      Fare Cabin Embarked
# 380      0    PC 17757  227.5250   NaN        C
# 310      0       11767   83.1583   C54        C
# 272      1      250644   19.5000   NaN        S
# 411      0      394140    6.8583   NaN        Q
# 432      0  SC/AH 3085   26.0000   NaN        S

# %%
# 5. Find the total number of rows and columns in the dataset.
df.shape
# Out:
# (891, 12)

# %%
#6. Print all column names.
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# 7. Display complete information about the dataset using info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# 8. Display the statistical summary of all numerical columns.
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# 9. Create a new DataFrame named df_small containing only the first 20 rows.
df_small = df.head(20)
df_small
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
# 10. Create another DataFrame containing only the
# columns Name , Age , Sex , and Fare
new_df = df[['Name','Age','Sex','Fare' ]]
new_df
# Out:
#                                                   Name   Age     Sex     Fare
# 0                              Braund, Mr. Owen Harris  22.0    male   7.2500
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female  71.2833
# 2                               Heikkinen, Miss. Laina  26.0  female   7.9250
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female  53.1000
# 4                             Allen, Mr. William Henry  35.0    male   8.0500
# ..                                                 ...   ...     ...      ...
# 886                              Montvila, Rev. Juozas  27.0    male  13.0000
# 887                       Graham, Miss. Margaret Edith  19.0  female  30.0000
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN  female  23.4500
# 889                              Behr, Mr. Karl Howell  26.0    male  30.0000
# 890                                Dooley, Mr. Patrick  32.0    male   7.7500
#
# [891 rows x 4 columns]

# %%
# 11. Select only the Age column.
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
# 12. Select the columns Name , Pclass , and Survived .
df[['Name','Pclass','Survived']]
# Out:
#                                                   Name  Pclass  Survived
# 0                              Braund, Mr. Owen Harris       3         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       1         1
# 2                               Heikkinen, Miss. Laina       3         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       1         1
# 4                             Allen, Mr. William Henry       3         0
# ..                                                 ...     ...       ...
# 886                              Montvila, Rev. Juozas       2         0
# 887                       Graham, Miss. Margaret Edith       1         1
# 888           Johnston, Miss. Catherine Helen "Carrie"       3         0
# 889                              Behr, Mr. Karl Howell       1         1
# 890                                Dooley, Mr. Patrick       3         0
#
# [891 rows x 3 columns]

# %%
# 13. Select the first row using iloc .
df.iloc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
# 14. Select rows 10 to 20 using iloc .
df.iloc[10:21]
# Out:
#     PassengerId  Survived  Pclass  \
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
#
#                                                  Name     Sex   Age  SibSp  \
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ...

# %%
# 15. Select rows 50 to 60 and columns Name and Fare .
df.loc[50:60, ['Name', 'Fare']]
# Out:
#                                                  Name     Fare
# 50                         Panula, Master. Juha Niilo  39.6875
# 51                       Nosworthy, Mr. Richard Cater   7.8000
# 52           Harper, Mrs. Henry Sleeper (Myna Haxtun)  76.7292
# 53  Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkin...  26.0000
# 54                     Ostby, Mr. Engelhart Cornelius  61.9792
# 55                                  Woolner, Mr. Hugh  35.5000
# 56                                  Rugg, Miss. Emily  10.5000
# 57                                Novel, Mr. Mansouer   7.2292
# 58                       West, Miss. Constance Mirium  27.7500
# 59                 Goodwin, Master. William Frederick  46.9000
# 60                              Sirayanian, Mr. Orsen   7.2292

# %%
# 16. Select the passenger name in the 100th row.
df.loc[ 100,'Name']
# Out:
# 'Petranec, Miss. Matilda'

# %%
# 17. Select the last 15 rows of the dataset.
df.tail(15)
# Out:
#      PassengerId  Survived  Pclass  \
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                               Name     Sex   Age  SibSp  \
# 876                  Gustafsson, Mr. Alfred Ossian    male  20.0      0
# 877                           Petroff, Mr. Nedelio    male  19.0      0
# 878                             Laleff, Mr. Kristo    male   NaN      0
# 879  Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# ...

# %%
# 18. Select all passengers whose names start with the letter A .
df[df['Name'].str.startswith('A')]
# Out:
#      PassengerId  Survived  Pclass  \
# 4              5         0       3
# 13            14         0       3
# 25            26         1       3
# 40            41         0       3
# 49            50         0       3
# 68            69         1       3
# 91            92         0       3
# 114          115         0       3
# 119          120         0       3
# 144          145         0       2
# 146          147         1       3
# 182          183         0       3
# 192          193         1       3
# 207          208         1       3
# 210          211         0       3
# 233          234         1       3
# 244          245         0       3
# 261          262         1       3
# 275          276         1       1
# 279          280         1       3
# 297          298         0       1
# 305          306         1       1
# 308          309         0       2
# 353          354         0       3
# 363          364         0       3
# ...

# %%
# 19. Select the Fare values of the first 25 passengers.
df['Fare'].head(25)
# Out:
# 0      7.2500
# 1     71.2833
# 2      7.9250
# 3     53.1000
# 4      8.0500
# 5      8.4583
# 6     51.8625
# 7     21.0750
# 8     11.1333
# 9     30.0708
# 10    16.7000
# 11    26.5500
# 12     8.0500
# 13    31.2750
# 14     7.8542
# 15    16.0000
# 16    29.1250
# 17    13.0000
# 18    18.0000
# 19     7.2250
# 20    26.0000
# 21    13.0000
# 22     8.0292
# 23    35.5000
# 24    21.0750
# Name: Fare, dtype: float64

# %%
# 20. Select rows where PassengerId is between 200 and 220.
df.loc[200:221, 'PassengerId']
# Out:
# 200    201
# 201    202
# 202    203
# 203    204
# 204    205
# 205    206
# 206    207
# 207    208
# 208    209
# 209    210
# 210    211
# 211    212
# 212    213
# 213    214
# 214    215
# 215    216
# 216    217
# 217    218
# 218    219
# 219    220
# 220    221
# 221    222
# Name: PassengerId, dtype: int64

# %%
# 31. Create a column Family_Size = SibSp + Parch + 1 .
df['Family_Size'] = df['SibSp'] + df['Parch'] + 1
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 32. Create a column Fare_with_Tax = Fare * 1.18 .
df['Fare_with_Tax'] = df['Fare'] * 1.18
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 33. Create a column Is_Child that is True if age is less than 18.
df['Is_Child'] = df['Age']< 18
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 34. Create a column Name_Length containing the length of each passenger's name
df['Name_Length'] = df['Name'].str.len()
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 35. Create a column Fare_Category where:
# Fare > 100 → Very High
# Fare > 50 → High
# Otherwise → Low

# %%
# 36. Increase all fares by 10%.
df['Fare'] = df['Fare']*10
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 37. Replace all missing values in Embarked with Unknown .
df['Embarked'] = df['Embarked'].fillna('Unknown')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 38. Convert values in Sex from male/female to M/F .
df['Sex'] = df['Sex'].replace({
    'male': 'm',
    'female' : 'f'
})
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris   m  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   f  38.0      1
# 2                               Heikkinen, Miss. Laina   f  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   f  35.0      1
# 4                             Allen, Mr. William Henry   m  35.0      0
# ..                                                 ...  ..   ...    ...
# ...

# %%
# 39. Set the fare of the first passenger to 999.
df.loc[0,'Fare'] = 999
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris   m  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   f  38.0      1
# 2                               Heikkinen, Miss. Laina   f  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   f  35.0      1
# 4                             Allen, Mr. William Henry   m  35.0      0
# ..                                                 ...  ..   ...    ...
# ...

# %%
# 40. Increase the age of all passengers by 1 year.
df['Age'] = df['Age']+1
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris   m  24.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   f  40.0      1
# 2                               Heikkinen, Miss. Laina   f  28.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   f  37.0      1
# 4                             Allen, Mr. William Henry   m  37.0      0
# ..                                                 ...  ..   ...    ...
# ...

# %%
# Out:
#   File "/tmp/ipykernel_1699/1151858552.py", line 2
#     df = df.drop['Cabin', axis = 1]
#                           ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?
